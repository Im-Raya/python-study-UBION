# %%
import csv

f= open('./data/age.csv' ,'r',encoding='cp949')
data= csv.reader(f)

for row in data:
    print(row)
    break

f.close()
# Out:
# ['행정구역', '2025년07월_계_총인구수', '2025년07월_계_연령구간인구수', '2025년07월_계_0세', '2025년07월_계_1세', '2025년07월_계_2세', '2025년07월_계_3세', '2025년07월_계_4세', '2025년07월_계_5세', '2025년07월_계_6세', '2025년07월_계_7세', '2025년07월_계_8세', '2025년07월_계_9세', '2025년07월_계_10세', '2025년07월_계_11세', '2025년07월_계_12세', '2025년07월_계_13세', '2025년07월_계_14세', '2025년07월_계_15세', '2025년07월_계_16세', '2025년07월_계_17세', '2025년07월_계_18세', '2025년07월_계_19세', '2025년07월_계_20세', '2025년07월_계_21세', '2025년07월_계_22세', '2025년07월_계_23세', '2025년07월_계_24세', '2025년07월_계_25세', '2025년07월_계_26세', '2025년07월_계_27세', '2025년07월_계_28세', '2025년07월_계_29세', '2025년07월_계_30세', '2025년07월_계_31세', '2025년07월_계_32세', '2025년07월_계_33세', '2025년07월_계_34세', '2025년07월_계_35세', '2025년07월_계_36세', '2025년07월_계_37세', '2025년07월_계_38세', '2025년07월_계_39세', '2025년07월_계_40세', '2025년07월_계_41세', '2025년07월_계_42세', '2025년07월_계_43세', '2025년07월_계_44세', '2025년07월_계_45세', '2025년07월_계_46세', '2025년07월_계_47세', '2025년07월_계_48세', '2025년07월_계_49세', '2025년07월_계_50세', '2025년07월_계_51세', '2025년07월_계_52세', '202
# ...

# %% [markdown]
# * 신도림동만 선택해서 출력

# %%
import csv

f= open('./data/age.csv' ,'r',encoding='cp949')
data= csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        print(row)
    

f.close()
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '35,813', '35,813', '252', '239', '225', '229', '234', '262', '306', '290', '323', '371', '413', '390', '369', '383', '382', '343', '360', '361', '311', '315', '296', '337', '326', '345', '390', '401', '402', '442', '500', '561', '494', '562', '623', '611', '598', '526', '587', '604', '638', '587', '613', '657', '698', '681', '719', '646', '655', '587', '591', '536', '603', '619', '635', '578', '562', '572', '522', '433', '450', '436', '472', '405', '430', '421', '495', '440', '405', '400', '372', '383', '379', '325', '312', '273', '210', '262', '229', '230', '212', '140', '126', '119', '118', '118', '92', '72', '76', '72', '53', '56', '34', '34', '19', '12', '11', '3', '5', '9', '2', '3', '3']

# %%
import csv

f= open('./data/age.csv' ,'r',encoding='cp949')
data= csv.reader(f)

result=[] #0~100세까지의 인구 데이터 담기(신도림)
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i)) #문자열 → 정수로 변환 후 리스트에 추가
    
f.close()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
import csv

f= open('./data/age.csv' ,'r',encoding='cp949')
data= csv.reader(f)

result=[] #0~100세까지의 인구 데이터 담기(신도림)
name= input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요')

for row in data:
    if name in row[0]: # input 받아서 처리
        for i in row[3:]:
            result.append(int(i)) #문자열 → 정수로 변환 후 리스트에 추가
    
f.close()

plt.style.use('ggplot')
plt.plot(result)
plt.title(name+'지역의 인구 구조')
plt.rc('font',family='malgun gothic')
plt.show()

# 테스트 아름동
# Out:
# c:\Users\LG\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\LG\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47492 (\N{HANGUL SYLLABLE REUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\LG\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\LG\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\LG\miniconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from font(s) DejaVu Sans.
# ...

# %% [markdown]
# # 막대그래프

# %%
import matplotlib.pyplot as plt

plt.bar([0,1,2,4,6,10],[1,2,3,5,6,7])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(range(6),[1,2,3,5,6,7])
plt.show()

# %%
# 막대 그래프로 출력
import csv

f= open('./data/age.csv' ,'r',encoding='cp949')
data= csv.reader(f)

result=[] #0~100세까지의 인구 데이터 담기(신도림)
name= input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요')

for row in data:
    if name in row[0]: # input 받아서 처리
        for i in row[3:]:
            result.append(int(i)) #문자열 → 정수로 변환 후 리스트에 추가
    
f.close()

plt.bar(range(101),result)
plt.show()

# %%
plt.barh(range(101),result)
plt.show()

# %% [markdown]
# * 항아리 그래프

# %% [markdown]
# * 구현 순서
#     * 남성 데이터 리스트m에 저장
#     * 여성 데이터 리스트f에 저장
#     * reverse() 함수를 이용해서 f 리스트 값을 역순으로 재배열

# %%
import csv
f= open('./data/gender(1).csv' ,'r',encoding='cp949')
data= csv.reader(f)

m=[]
f=[]

for row in data:
    if '신도림'in row[0]:
        for i in range(0,101):
            m.append(-int(row[i+3])) #인구 피라미드를 그릴 때 양쪽으로 나뉘어 보이도록 하기 위해 
            f.append(int(row[-(i+1)])) #남성 데이터를 음수(–)
            
        
f.reverse()
plt.rc('font',family='malgun gothic')
plt.title('신도림 지역의 남녀 성별 인구 분포')
plt.rcParams['axes.unicode_minus'] = False
plt.barh(range(101), m, label='남성')
plt.barh(range(101), f, label='여성')
plt.legend()
plt.show()

# %%
# 랜덤 지역+성별
import csv
import matplotlib.pyplot as plt
f1 = open(r'./data/gender(1).csv', encoding='cp949')
data = csv.reader(f1)
m = []
f = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')

for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i))
        for i in row[106:] :
            f.append(int(i))
            
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title('특 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()

# 도담동

# %%
# 제주특별자치도 
# 그래프 데이터에 던지는 질문: 제주도에는 어떤 성별이 더 많이 살고 있는가?

import csv
import matplotlib.pyplot as plt
f1 = open(r'./data/gender(1).csv', encoding='cp949')
data = csv.reader(f1)
m = []
f = []
# name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
name = '제주특별자치도'  # test code
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(int(i))
        for i in row[106:] :
            f.append(int(i))
        break
    
plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title('특 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = '남성')
plt.barh(range(101), f, label = '여성')
plt.legend()
plt.show()

# %% [markdown]
# # 원 그래프

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.scatter([1,2,3,4],[10,30,20,40],s=[100,200,250,300])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c= ['red','blue','green','gold'])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c= range(4))
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c= range(4),cmap='jet')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import random

x=[]
y=[]
size=[]

for i in range(100):
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
            
plt.style.use('ggplot')
plt.scatter(x,y,s=size,c=size,cmap='jet',alpha=0.7) # alpha 투명도, 큰놈 뒤에 숨겨져 있는 작은놈 확인할 수 있다.
plt.colorbar()
plt.show()

# %%
import csv
f= open('./data/gender(1).csv' ,'r',encoding='cp949')
data= csv.reader(f)

m=[]
f=[]

name= '제주특별자치도'

for row in data:
    if name in row[0]: 
        for i in row[3:104]: # 3부터 103까지
            m.append(int(i)) 
        for i in row[106:]:
            f.append(int(i))
        break

plt.style.use('ggplot')
plt.scatter(m,f,c=range(101),cmap='jet',alpha=0.5)
plt.colorbar()
plt.plot(range(max(m)),range(max(m)),'g') # 추세
plt.show()

# %% [markdown]
# # 컬러 테이블

# %%
import csv
f= open('./data/gender(1).csv' ,'r',encoding='cp949')
data = csv.reader(f)
size = []
name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        m = 0
        f = 0
        for i in range(101) :
            m += int(row[i+3])
            f += int(row[i+106])
        break
size.append(m)
size.append(f)
import matplotlib.pyplot as plt
plt.rc('font', family ='Malgun Gothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels = ['남','여'], autopct ='%.1f%%', colors = color, startangle =90)
plt.title(name + ' 지역의 남녀 성별 비율')
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)
# Sort colors by hue, saturation, value and name.
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_names = [name for hsv, name in by_hsv]
n = len(sorted_names)
ncols = 4
nrows = n // ncols
fig, ax = plt.subplots(figsize=(9, 8), dpi = 300)
# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols
for i, name in enumerate(sorted_names):
    row = i % nrows
    col = i // nrows
    y = Y - (row * h) - h
    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)
    ax.text(xi_text, y, name, fontsize=(10),
            horizontalalignment='left',
            verticalalignment='center')
    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(6))
ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()
fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()
