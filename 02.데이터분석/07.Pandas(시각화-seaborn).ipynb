# %% [markdown]
# ### 데이터 가져오기

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')
print(titanic.head())
print(titanic.info())
print(titanic.shape)
print(titanic.describe())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %% [markdown]
# ### 회귀선이 있는 산점도 : regplot()
# * 서로 다른 2개의 연속변수 산점도

# %%
# 스타일 테마 설정 ( 5가지 : darkgrid, whitegride, dark, white, ticks 중 택 )
sns.set_style('darkgrid')

# 그래프 객체 생성 (figure에 2개의 서브 플롯을 생성) : 1행 2열  
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#그래프 그리기 - 선형회귀선 표시(fit_reg=True)
sns.regplot(x = 'age',  # x축 변수 
            y = 'fare', # y축 변수
            data = titanic, #데이터 
            ax =ax1);  # axe 객체 - 1번 그래프 

#그래프 그리기 - 선형회귀선 미표시(fit_reg=False)
sns.regplot(x = 'age',  # x축 변수 
            y = 'fare', # y축 변수
            data = titanic, #데이터 
            ax =ax2,  # axe 객체 - 1번 그래프 
            fit_reg=False ); #회귀선 미표시 

plt.show()

# %% [markdown]
# ### 히스토그램/커널 밀도 그래프 : distplot()
# * 단변수 (하나의 변수) 데이터의 분포를 확인

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')

sns.set_style('darkgrid')

#그래프 객체 생성 (figure에 3개의 서브 플롯을 생성) : 1행 3열 
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

#distplot : 히스토그램 + KDE(커널 밀도 추정)그래프 
sns.distplot(titanic['fare'] ,ax= ax1) #seaborn ver 0.11이후에는 권장하지 않음. 

#kdeplot : KDE(커널 밀도 추정) 그래프 
sns.kdeplot(x='fare', data=titanic, ax=ax2)

#histplot : 히스토그램 
sns.histplot(x='fare', data=titanic, ax=ax3)

#차트 제목 표시
ax1.set_title('titanic fare - distplot')
ax2.set_title('titanic fare - kdeplot')
ax3.set_title('titanic fare - histplot ')

plt.show()

# %% [markdown]
# ### heatmap
# * 데이터 값을 색상으로 표현하는 그래프( 색의 진하기, 밝기, 톤)
# * 복잡한 수치 데이터도 시각적인 패턴으로 이해하기 쉬움

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')
sns.set_style('darkgrid')

# 피벗테이블로 범주형 변주를 각각 행, 열로 재구분하여 정리
table = titanic.pivot_table(index=['sex'], columns=['class'], aggfunc='size')

sns.heatmap( table,         # 데이터 프레임
            annot=True, fmt='d', # 데이터 값 표시 여부, 정수형 포맷
            cmap='YlGnBu',  # 컬러 맵 
            linewidths= .5, # 구분 선
            cbar=False) # 컬러 바 표시 여부 

plt.show()

# %% [markdown]
# ### 범주형 데이터 산점도 : stripplot(), swarmplot()
# * 데이터가 퍼져 있는 정도를 입체적으로 볼 수 있음

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')
sns.set_style('darkgrid')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)


# 이산형 변수의 분포 - 데이터 분산 미고려 
# 점들이 포개져 있으면 그대로 표현하기 때문에 데이터 분산까지 보여주지 못함. 

sns.stripplot( x= "class",  # x축 변수 
              y="age",      # y축 변수 
              data=titanic, # 데이터 셋 - 프레임
              ax=ax1);       # axe객체 - 1번째 프레임 

sns.swarmplot( x= "class",  # x축 변수 
              y="age",      # y축 변수 
              data=titanic, # 데이터 셋 - 프레임
              ax=ax2);       # axe객체 - 1번째 프레임 

# 차트 제복표시
ax1.set_title('Strip Plot')
ax1.set_title('Strip Plot')
# Out:
# Text(0.5, 1.0, 'Strip Plot')

# %% [markdown]
# ### bar 그래프

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')

sns.set_style('darkgrid')

#그래프 객체 생성 (figure에 3개의 서브 플롯을 생성) : 1행 3열 
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

#단순 bar 그래프
sns.barplot(x='sex', y='survived', data=titanic, ax=ax1)

#hue 옵션을 추가
sns.barplot(x='sex', y='survived', hue='class', data=titanic, ax=ax2)

#dodge 옵션을 추가 
sns.barplot(x='sex', y='survived', hue='class',dodge=False, data=titanic, ax=ax3)

#차트 제목 표시
# 차트 제목 표시
ax1.set_title('titanic survived - sex')
ax2.set_title('titanic survived - sex/class')
ax3.set_title('titanic survived - sex/class(stacked)')


plt.show()

# %% [markdown]
# # 빈도 그래프 : countplot()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')

sns.set_style('darkgrid')

#그래프 객체 생성 (figure에 3개의 서브 플롯을 생성) : 1행 3열 
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

# 기본값 
sns.countplot(x='class', palette='Set1', data=titanic, ax=ax1)

#hue 옵션에 who추가
sns.countplot(x='class', hue='who', palette='Set2', data=titanic, ax=ax2)

#누적 그래프 출력 
sns.countplot(x='class', hue='who', palette='Set3',dodge=False, data=titanic, ax=ax3)

# 차트 제목 표시
ax1.set_title('titanic class')
ax2.set_title('titanic class - who')
ax3.set_title('titanic class - who(stacked)')
plt.show()

# %% [markdown]
# # 박스 그래프, 바이올린 그래프

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')

sns.set_style('darkgrid')

#그래프 객체 생성 (figure에 3개의 서브 플롯을 생성) : 1행 3열 
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

#박스 - 기본값
sns.boxplot(x='alive', y='age', data=titanic, ax=ax1)

#hue 옵션을 추가
sns.boxplot(x='alive', y='age', hue='sex', data=titanic, ax=ax2)

#바이올린 그래프 
    # 데이터 분포의 밀도를 곡선 형태로 보여줌 

#바이올린- 기본값
sns.violinplot(x='alive', y='age', data=titanic, ax=ax3)

#hue 옵션을 추가
sns.violinplot(x='alive', y='age', hue='sex', data=titanic, ax=ax4)

plt.show()
